# %%
import pandas as pd
df_apps = pd.read_csv('/AppleStore.csv')

# %%
df_apps.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
df_apps.drop(df_apps.columns[[0]], axis=1, inplace=True)

# %%
df_apps.isnull().any()
# Out:
# id                  False
# track_name          False
# size_bytes          False
# currency            False
# price               False
# rating_count_tot    False
# rating_count_ver    False
# user_rating         False
# user_rating_ver     False
# ver                 False
# cont_rating         False
# prime_genre         False
# sup_devices.num     False
# ipadSc_urls.num     False
# lang.num            False
# vpp_lic             False
# dtype: bool

# %%
#check info about the first AppleStore's app
df_apps.iloc[0]
# Out:
# id                        281656475
# track_name          PAC-MAN Premium
# size_bytes                100788224
# currency                        USD
# price                          3.99
# rating_count_tot              21292
# rating_count_ver                 26
# user_rating                     4.0
# user_rating_ver                 4.5
# ver                           6.3.5
# cont_rating                      4+
# prime_genre                   Games
# sup_devices.num                  38
# ipadSc_urls.num                   5
# lang.num                         10
# vpp_lic                           1
# Name: 0, dtype: object

# %%
#check names of the first five apps
df_apps['track_name'].head()
# Out:
# 0                                      PAC-MAN Premium
# 1                            Evernote - stay organized
# 2      WeatherBug - Local Weather, Radar, Maps, Alerts
# 3    eBay: Best App to Buy, Sell, Save! Online Shop...
# 4                                                Bible
# Name: track_name, dtype: object

# %%
#create a dataframe for the first five App's names
df_apps[['track_name']].head()
# Out:
#                                           track_name
# 0                                    PAC-MAN Premium
# 1                          Evernote - stay organized
# 2    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4                                              Bible

# %%
#create a dataframe for apps with a category Productivity
df_apps[df_apps['prime_genre']== 'Productivity']
# Out:
#               id                                     track_name  size_bytes  \
# 1      281796108                      Evernote - stay organized   158578688
# 27     288113403  iTranslate - Language Translator & Dictionary   287933440
# 126    310636441      iStudiez Pro – Homework, Schedule, Grades    55815168
# 132    311785642     AutoScout24 - mobile used & new car market   141136896
# 134    312220102             MindNode – Delightful Mind Mapping    52294656
# ...          ...                                            ...         ...
# 6786  1147667378                                    Digiposte +   106643456
# 6789  1147923152      Timepage for iPad – Calendar by Moleskine    85417984
# 6803  1148364175                                  My PriceQuote    21143552
# 6981  1163668736     One Touch Camera Recording & Capture in HD     1327104
# 7077  1173333213                                ContactsXL 2017    16477184
#
# ...

# %%
#check apps which have a rating more than 4.5
df_apps[df_apps['user_rating']>4.5]
# Out:
#               id                                         track_name  \
# 21     285994151                                        :) Sudoku +
# 230    335545504                                King of Dragon Pass
# 271    342548956  TurboScan™ Pro - document & receipt scanner: s...
# 302    350642635                                 Plants vs. Zombies
# 318    353372460        Learn to Speak Spanish Fast With MosaLingua
# ...          ...                                                ...
# 7166  1181904201   4x4 Dirt Track Trials Forest Driving Parking Sim
# 7170  1183234072                                          CTFxCmoji
# 7171  1183260922                    Room Escape Game - Santa's Room
# 7180  1185365336                   Laurie Hernandez the Human Emoji
# 7196  1188375727                       Escape the Sweet Shop Series
#
#       size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 21       6169600      USD   2.99             11447               781
# ...

# %%
#check apps which have a rating 5
df_apps[df_apps['user_rating'] == 5]
# Out:
#               id                                         track_name  \
# 21     285994151                                        :) Sudoku +
# 230    335545504                                King of Dragon Pass
# 271    342548956  TurboScan™ Pro - document & receipt scanner: s...
# 302    350642635                                 Plants vs. Zombies
# 318    353372460        Learn to Speak Spanish Fast With MosaLingua
# ...          ...                                                ...
# 7166  1181904201   4x4 Dirt Track Trials Forest Driving Parking Sim
# 7170  1183234072                                          CTFxCmoji
# 7171  1183260922                    Room Escape Game - Santa's Room
# 7180  1185365336                   Laurie Hernandez the Human Emoji
# 7196  1188375727                       Escape the Sweet Shop Series
#
#       size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 21       6169600      USD   2.99             11447               781
# ...

# %%
#check apps which have a rating more than 4.7 in category Shopping
df_apps[(df_apps['user_rating'] >4.7) & (df_apps['prime_genre'] == 'Shopping')]
# Out:
#               id                                         track_name  \
# 545    392988420   Zappos: shop shoes & clothes, fast free shipping
# 896    452176796                                  蘑菇街-网红直播搭配的购物特卖平台
# 929    457876088                                               ASOS
# 1435   544118997  Shopular Coupons, Weekly Deals for Target, Wal...
# 1557   563764220                     minne - shopping handmade item
# 2239   723134859   Ebates: Cash Back, Coupons & Rebate Shopping App
# 2530   836767708  Wayfair - Shop Furniture, Home Decor, Daily Sales
# 3836   999183538            Honest App: Shop baby & diaper products
# 4678  1056489580                                        棒棒糖-宝宝的世界衣橱
# 5335  1080248000         Romwe shopping- Fashion Clothing for women
# 5747  1095459556                                              Nike+
# 5749  1095571204                       KIXIFY - Buy & Sell Sneakers
#
#       size_bytes currency  price  rating_count_tot  rating_count_ver  \
# ...

# %%
df_apps.groupby(['prime_genre'])['user_rating'].mean().sort_values(ascending = False)
# Out:
# prime_genre
# Productivity         4.005618
# Music                3.978261
# Photo & Video        3.800860
# Business             3.745614
# Health & Fitness     3.700000
# Games                3.685008
# Weather              3.597222
# Shopping             3.540984
# Reference            3.453125
# Travel               3.376543
# Education            3.376380
# Medical              3.369565
# Utilities            3.278226
# Entertainment        3.246729
# Food & Drink         3.182540
# Social Networking    2.985030
# Sports               2.982456
# News                 2.980000
# Lifestyle            2.805556
# Navigation           2.684783
# Book                 2.477679
# Finance              2.432692
# Catalogs             2.100000
# Name: user_rating, dtype: float64

# %%
#descriptive statistics
df_apps.describe()
# Out:
#                  id    size_bytes        price  rating_count_tot  \
# count  7.197000e+03  7.197000e+03  7197.000000      7.197000e+03
# mean   8.631310e+08  1.991345e+08     1.726218      1.289291e+04
# std    2.712368e+08  3.592069e+08     5.833006      7.573941e+04
# min    2.816565e+08  5.898240e+05     0.000000      0.000000e+00
# 25%    6.000937e+08  4.692275e+07     0.000000      2.800000e+01
# 50%    9.781482e+08  9.715302e+07     0.000000      3.000000e+02
# 75%    1.082310e+09  1.819249e+08     1.990000      2.793000e+03
# max    1.188376e+09  4.025970e+09   299.990000      2.974676e+06
#
#        rating_count_ver  user_rating  user_rating_ver  sup_devices.num  \
# count       7197.000000  7197.000000      7197.000000      7197.000000
# mean         460.373906     3.526956         3.253578        37.361817
# std         3920.455183     1.517948         1.809363         3.737715
# min            0.000000     0.000000         0.000000         9.000000
# ...

# %%
#Drop all the null values in df
#check df's info without null values
df_apps_dropped = df_apps.dropna()
df_apps_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                7197 non-null   int64
#  1   track_name        7197 non-null   object
#  2   size_bytes        7197 non-null   int64
#  3   currency          7197 non-null   object
#  4   price             7197 non-null   float64
#  5   rating_count_tot  7197 non-null   int64
#  6   rating_count_ver  7197 non-null   int64
#  7   user_rating       7197 non-null   float64
#  8   user_rating_ver   7197 non-null   float64
#  9   ver               7197 non-null   object
#  10  cont_rating       7197 non-null   object
#  11  prime_genre       7197 non-null   object
#  12  sup_devices.num   7197 non-null   int64
#  13  ipadSc_urls.num   7197 non-null   int64
#  14  lang.num          7197 non-null   int64
#  15  vpp_lic           7197 non-null   int64
# ...

# %%
#print the unique category names
df_apps['prime_genre'].unique()
# Out:
# array(['Games', 'Productivity', 'Weather', 'Shopping', 'Reference',
#        'Finance', 'Music', 'Utilities', 'Travel', 'Social Networking',
#        'Sports', 'Business', 'Health & Fitness', 'Entertainment',
#        'Photo & Video', 'Navigation', 'Education', 'Lifestyle',
#        'Food & Drink', 'News', 'Book', 'Medical', 'Catalogs'],
#       dtype=object)

# %%
#print the number of nunique category names
df_apps['prime_genre'].nunique()
# Out:
# 23

# %%
#create a dataframe where content rating is everyone and type is paid
df_apps[(df_apps['cont_rating'] == '12+') & (df_apps['price'] > 0.00)]
# Out:
#               id                                    track_name  size_bytes  \
# 31     289084315                         Period Tracker Deluxe    40216576
# 55     295775656  12 Steps AA Companion - Alcoholics Anonymous    30367744
# 90     304871622                               Zombieville USA    27962441
# 114    308339980                    iRagdoll - Ragdoll Physics   118683648
# 122    309527804                                     StickWars    17010688
# ...          ...                                           ...         ...
# 7146  1180300366           Pitmoji - Pit Bull Emoji & Stickers    32785408
# 7152  1180931796                               椅子ドンVR~一ノ宮英介 編~   161346560
# 7156  1181025437                          Demi Lovato Stickers    88388608
# 7160  1181582218         Addon Creator Studio for Minecraft PE    61915136
# 7164  1181724803                                ＣＲスーパー海物語ＩＮ沖縄４  3503480832
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
#check first 20 apps with a rating more than 4.7
best_apps = df_apps[df_apps['user_rating']>= 4.7].head(20)
best_apps
# Out:
#             id                                         track_name  size_bytes  \
# 21   285994151                                        :) Sudoku +     6169600
# 230  335545504                                King of Dragon Pass   364490752
# 271  342548956  TurboScan™ Pro - document & receipt scanner: s...     8821760
# 302  350642635                                 Plants vs. Zombies   105379840
# 318  353372460        Learn to Speak Spanish Fast With MosaLingua    48819200
# 350  363282253                              Plants vs. Zombies HD   225859584
# 383  366195670                       The Photographer's Ephemeris    58463232
# 410  372283316                                          ▻Sudoku +    61595648
# 467  381471023                                       Flashlight Ⓞ    42027008
# 498  387428400                                     Infinity Blade   624107810
# 545  392988420   Zappos: shop shoes & clothes, fast free shipping    70325248
# ...

# %%
#histogram for the first 10 apps which have a category Games
df_games_apps = df_apps[df_apps['prime_genre'] == 'Games'].sort_values(by = 'user_rating', ascending = False).head(10)

# %%
df_games_apps
# Out:
#               id                                         track_name  \
# 7196  1188375727                       Escape the Sweet Shop Series
# 6546  1134835650                               Mystery of Fortune 2
# 1828   608899141                          Cut the Rope: Time Travel
# 1827   608847384                            X-War: Clash of Zombies
# 6564  1135518748                              Suрer Toss The Turtle
# 5572  1088300283  Vintage Slots Las Vegas - Old Slot Machine Games!
# 1817   606190854                                         Iron Force
# 6579  1136075542                                 Escape Game: Traps
# 5566  1088172195                                Escape Game: Relief
# 1802   600674056  Pictoword: Fun 2 Pics Guess What's the Word Tr...
#
#       size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 7196    90898432      USD   0.00                 3                 3
# 6546   114503680      USD   0.99                19                 0
# ...

# %%
plt.figure(figsize = (12, 6))
plt.xticks(rotation = 90)
plt.bar(df_games_apps['track_name'], df_beauty_apps['user_rating'])
# Out:
# <BarContainer object of 10 artists>

# %%
df_20 = df_apps[['track_name', 'user_rating']].head(20).sort_values(by = 'user_rating', ascending = False)

# %%
plt.figure(figsize = (12, 6))
plt.xticks(rotation = 90)
plt.bar(df_20['track_name'], df_20['user_rating'])
plt.xlabel('track_name')
plt.ylabel('user_Rating')
plt.title('AppleStore apps distribution by rating')
# Out:
# Text(0.5, 1.0, 'AppleStore apps distribution by rating')

# %%
#make a horizontal bar plot
plt.figure(figsize = (12,6))
plt.barh(df_20['track_name'], df_20['user_rating'])
plt.xlabel('track_name')
plt.ylabel('user_rating')
plt.title('AppleStore apps distribution by rating (horizontal)')
# Out:
# Text(0.5, 1.0, 'AppleStore apps distribution by rating (horizontal)')

# %%
#create a histogram
plt.figure(figsize = (12,6))
plt.hist(df_apps['user_rating'], color = 'r')
# Out:
# (array([ 929.,    0.,   44.,   56.,  106.,  196.,  383.,  702., 1626.,
#         3155.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
#create a new subplot
plt.figure(figsize = (15,13))

plt.subplot(2,2,1)
plt.hist(df_apps['user_rating'], color = 'r')

plt.subplot(2,2,2)
plt.xticks(rotation = 90)
plt.bar(df_20['track_name'], df_20['user_rating'])

plt.show()
